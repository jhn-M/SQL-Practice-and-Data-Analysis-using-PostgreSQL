# %% [markdown]
# # HR Dataset Input to SQL and Observation

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\Marry Bless Magat\Documents\lenon files\Projects\SQL-Practice-and-Data-Analysis-using-PostgreSQL\Project\Dataset\hr_raw.csv")

# %%
from sqlalchemy import create_engine

engine = create_engine('mysql+pymysql://root:lenon03@localhost/hr_project')

df.to_sql('hr_data', con=engine, if_exists='replace', index=False, chunksize=10000)
# Out:
# 2000000

# %%
df
# Out:
#         Employee_ID                             Full_Name  Department  \
# 0        EMP0000001                     Heinz-Georg Eimer       Sales
# 1        EMP0000002  Maartje van den Nuwenhuysen-Geertsen          HR
# 2        EMP0000003                  Sara Sureda Figueroa          HR
# 3        EMP0000004                          Luce Sanchez  Operations
# 4        EMP0000005                      William Jennings       Sales
# ...             ...                                   ...         ...
# 1999995  EMP1999996                Ottmar Kusch-Dörschner          IT
# 1999996  EMP1999997                       Isis Wagenvoort       Sales
# 1999997  EMP1999998                    Ángel Gomez Arenas       Sales
# 1999998  EMP1999999                          Carmela Weiß       Sales
# 1999999  EMP2000000                        Macario Casals          IT
#
#                     Job_Title   Hire_Date Performance_Rating  \
# 0        Business Development  2023-01-31       Satisfactory
# 1                  HR Manager  2008-11-07               Good
# 2           Talent Specialist  2016-03-19  Needs Improvement
# 3         Operations Director  2024-04-03               Good
# 4               Regional Lead  2024-11-17               Good
# ...                       ...         ...                ...
# 1999995    Software Developer  2020-11-30               Good
# 1999996         Sales Manager  2024-06-06               Good
# 1999997         Sales Manager  2020-05-21          Excellent
# 1999998  Business Development  2018-07-11          Excellent
# 1999999    Software Developer  2025-09-11               Good
#
#          Experience_Years  Status Work_Mode    Salary  Year         Country  \
# 0                       8  Active   On-site   92992.0  2023         Germany
# 1                      11  Active   On-site  112318.0  2008     Netherlands
# 2                      15  Active   On-site  111121.0  2016           Spain
# 3                       1  Active    Hybrid   49012.0  2024          France
# 4                       2  Active   On-site   57553.0  2024  United Kingdom
# ...                   ...     ...       ...       ...   ...             ...
# 1999995                15  Active    Hybrid  136684.0  2020         Germany
# 1999996                 3  Active   On-site   57911.0  2024     Netherlands
# 1999997                14  Active    Remote  146065.0  2020           Spain
# 1999998                 9  Active    Remote  138855.0  2018         Germany
# 1999999                 1  Active    Hybrid   46067.0  2025           Spain
#
#               City  Age Job_Level
# 0           Munich   32       Mid
# 1        Eindhoven   43    Senior
# 2          Seville   43    Senior
# 3        Marseille   23    Junior
# 4        Edinburgh   31    Junior
# ...            ...  ...       ...
# 1999995  Frankfurt   44    Senior
# 1999996  Amsterdam   25    Junior
# 1999997   Valencia   39    Senior
# 1999998  Frankfurt   35    Senior
# 1999999     Madrid   28    Junior
#
# [2000000 rows x 15 columns]
